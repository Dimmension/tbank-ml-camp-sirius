# %%
import json
import pandas as pd
import ast

# %%
df = pd.read_csv('../data/label_desc_context_nearest_many.csv').dropna()
data = {row['intent']: ast.literal_eval(row['nearest_labels']) for i, row in df.iterrows()}

# %%
data
# Out:
# {'accept_reservations': ['definition',
#   'travel_alert',
#   'restaurant_reservation'],
#  'account_blocked': ['balance', 'freeze_account', 'card_declined'],
#  'alarm': ['translate', 'timer'],
#  'application_status': ['credit_limit', 'order_status', 'credit_limit_change'],
#  'apr': ['new_card', 'credit_limit', 'interest_rate'],
#  'are_you_a_bot': ['change_user_name',
#   'where_are_you_from',
#   'how_old_are_you'],
#  'balance': ['payday', 'application_status', 'transactions'],
#  'bill_balance': ['balance', 'pay_bill', 'bill_due'],
#  'bill_due': ['improve_credit_score', 'payday', 'bill_balance'],
#  'book_flight': ['translate', 'travel_alert', 'flight_status'],
#  'book_hotel': ['timer', 'restaurant_reservation', 'car_rental'],
#  'calculator': ['definition', 'what_can_i_ask_you', 'taxes'],
#  'calendar': ['payday', 'date', 'meeting_schedule'],
#  'calendar_update': ['todo_list_update', 'calendar', 'schedule_meeting'],
# ...

# %%
with open("nearest_labels.json", "w") as f:
    json.dump(data, f, indent=4)

# %%
array
# Out:
# ['definition', 'travel_alert', 'restaurant_reservation']
